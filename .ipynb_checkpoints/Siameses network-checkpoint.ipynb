# %% [markdown]
# # One Shot Learning with Siamese Networks

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import mxnet as mx
from mxnet import gluon
from mxnet.gluon.data.vision import ImageFolderDataset
from mxnet.gluon.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import numpy as np
import random
from PIL import Image
import PIL.ImageOps 
import mxnet.ndarray as nd
from mxnet.gluon import nn
from mxnet import autograd

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "/Users/dongshouyang/project/face_recognition/training/"
    testing_dir = "/Users/dongshouyang/project/face_recognition/validation/"
    train_batch_size = 90
    train_number_epochs = 100

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for genuine pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=True,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            img1_tuple = random.choice(self.imageFolderDataset)

        img0 = (img0_tuple[0]).asnumpy()
        img1 = (img1_tuple[0]).asnumpy()
        img0= Image.fromarray(img0)
        img1= Image.fromarray(img1)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        img0 = np.asarray(img0,dtype=np.float32)
        img1 = np.asarray(img1,dtype=np.float32)
        img0 = img0.reshape((1, 112, 92))
        img1 = img1.reshape((1, 112, 92))
            
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform:
            img0 = mx.image.imresize(img0, 100, 100)
            img1 = mx.image.imresize(img1, 100, 100)
        return img0, img1 , nd.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32)
    
    def __len__(self):
        return len(self.imageFolderDataset)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = ImageFolderDataset(root=Config.training_dir)
folder_dataset

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=False
                                       ,should_invert=False)

# %%
image0, image1, label =siamese_dataset.__getitem__(index=2)
image0
# Out:
# array([[[  67.,   62.,   88., ...,  158.,  141.,  151.],
#         [  66.,   57.,   75., ...,  156.,  149.,  140.],
#         [  65.,   71.,   74., ...,  150.,  155.,  142.],
#         ...,
#         [  51.,   47.,   50., ...,  176.,  166.,  147.],
#         [  52.,   50.,   50., ...,  170.,  161.,  140.],
#         [  48.,   53.,   55., ...,  167.,  157.,  145.]]], dtype=float32)

# %%
vis_dataloader = DataLoader(siamese_dataset,batch_size=8,shuffle=True,num_workers=8)
vis_dataloader

# %%
dataiter = iter(vis_dataloader)
dataiter
# Out:
# <generator object DataLoader.__iter__ at 0x1a18d4eba0>

# %%
example_batch = next(dataiter)
example_batch
# Out:
# [
#  [[[[ 116.  116.  117. ...,  115.  110.  114.]
#     [ 116.  114.  116. ...,  113.  110.  112.]
#     [ 116.  112.  117. ...,  114.  111.  110.]
#     ...,
#     [  23.   22.   28. ...,   74.   69.   61.]
#     [  27.   29.   29. ...,   76.   76.   66.]
#     [  28.   27.   38. ...,   83.   76.   77.]]]
#
#
#   [[[ 101.   86.   71. ...,  101.  101.  102.]
#     [  92.   73.   69. ...,  100.  102.  103.]
#     [  85.   69.   77. ...,  101.  103.  103.]
#     ...,
#     [  78.   85.  161. ...,   76.   72.   79.]
#     [ 144.  155.  180. ...,   72.   77.   75.]
#     [ 171.  167.  186. ...,   81.  105.   87.]]]
#
#
#   [[[  29.   39.   35. ...,   32.   27.   37.]
#     [  33.   41.   37. ...,   39.   33.   34.]
#     [  35.   39.   39. ...,   34.   35.   34.]
#     ...,
#     [ 195.  201.  154. ...,  167.  189.  215.]
#     [ 190.  204.  147. ...,  196.  159.  220.]
#     [ 179.  189.  138. ...,  213.  153.  204.]]]
#
#
#   ...,
#   [[[  52.   41.   48. ...,   55.   54.   54.]
#     [  49.   46.   48. ...,   53.   56.   48.]
#     [  53.   46.   50. ...,   54.   54.   53.]
#     ...,
#     [  47.   38.   48. ...,   40.   53.   45.]
#     [  44.   43.   49. ...,   43.   49.   47.]
#     [  51.   76.   83. ...,   44.   43.   46.]]]
#
#
#   [[[  48.   48.   55. ...,   44.   46.   47.]
#     [  51.   47.   54. ...,   48.   47.   47.]
#     [  49.   56.   50. ...,   48.   46.   48.]
#     ...,
#     [ 107.   96.   59. ...,   94.   94.  108.]
#     [ 110.   89.   59. ...,   90.   98.  104.]
#     [ 110.   79.  116. ...,   88.   93.   99.]]]
#
#
#   [[[  50.   49.   50. ...,   41.   42.   38.]
#     [  55.   46.   50. ...,   39.   39.   36.]
#     [  50.   49.   49. ...,   37.   42.   38.]
#     ...,
#     [ 183.  165.  145. ...,  118.  114.  105.]
#     [ 133.  148.  155. ...,  120.  118.  116.]
#     [ 144.  150.  169. ...,  159.  111.  117.]]]]
#  <NDArray 8x1x112x92 @cpu_shared(0)>,
#  [[[[ 103.  104.  103. ...,  102.   99.  100.]
#     [ 104.  104.  104. ...,   98.  103.  105.]
#     [ 107.  104.  105. ...,  103.  104.  101.]
#     ...,
#     [ 128.  158.  171. ...,  133.  164.  143.]
#     [ 160.  165.  178. ...,  131.  165.  147.]
#     [ 155.  176.  177. ...,  132.  165.  149.]]]
#
#
#   [[[  98.   94.  100. ...,  102.   98.  102.]
#     [  94.   97.   99. ...,   98.  102.  104.]
#     [  94.   97.   97. ...,  100.  103.  100.]
#     ...,
#     [ 135.  168.  160. ...,  105.  122.  127.]
#     [ 166.  175.  173. ...,  165.  151.  153.]
#     [ 183.  173.  190. ...,  164.  167.  164.]]]
#
#
#   [[[  48.   47.   53. ...,   61.   59.   60.]
#     [  50.   48.   52. ...,   56.   61.   58.]
#     [  53.   47.   53. ...,   54.   64.   60.]
#     ...,
#     [  50.   55.   49. ...,   64.   67.   59.]
#     [  52.   50.   49. ...,   63.   65.   60.]
#     [  52.   49.   50. ...,   61.   66.   67.]]]
#
#
#   ...,
#   [[[ 104.  108.  105. ...,  104.  105.  108.]
#     [ 104.  106.  105. ...,  105.  106.  103.]
#     [ 105.  105.  108. ...,  102.  103.  106.]
#     ...,
#     [  83.   83.   99. ...,  163.  176.  141.]
#     [ 103.  124.  147. ...,  179.  164.  148.]
#     [ 160.  180.  156. ...,  173.  175.  155.]]]
#
#
#   [[[  44.   43.   32. ...,   52.   48.   52.]
#     [  44.   38.   33. ...,   51.   51.   54.]
#     [  41.   42.   29. ...,   50.   53.   53.]
#     ...,
#     [  39.   37.   39. ...,   41.   37.   37.]
#     [  41.   41.   38. ...,   44.   36.   32.]
#     [  40.   36.   42. ...,   43.   43.   37.]]]
#
#
#   [[[  43.   46.   43. ...,   35.   40.   38.]
#     [  46.   43.   43. ...,   38.   43.   37.]
#     [  49.   45.   43. ...,   40.   42.   34.]
#     ...,
#     [ 153.  146.  134. ...,  107.  170.  102.]
#     [ 146.  155.  120. ...,  103.  173.  139.]
#     [ 142.  142.  141. ...,   95.  162.  197.]]]]
#  <NDArray 8x1x112x92 @cpu_shared(0)>,
#  [[ 1.]
#   [ 0.]
#   [ 1.]
#   [ 0.]
#   [ 1.]
#   [ 1.]
#   [ 1.]
#   [ 0.]]
#  <NDArray 8x1 @cpu_shared(0)>]

# %%
example_batch[0]
# Out:
# [[[[ 106.  106.  110. ...,  104.  105.  103.]
#    [ 107.  106.  108. ...,  102.  104.  102.]
#    [ 107.  107.  107. ...,  101.  104.  103.]
#    ...,
#    [ 132.  177.  200. ...,   69.   69.   69.]
#    [ 185.  198.  203. ...,   69.   68.   68.]
#    [ 188.  199.  204. ...,   69.   69.   68.]]]
#
#
#  [[[  46.   45.   47. ...,   47.   46.   48.]
#    [  45.   48.   42. ...,   46.   46.   47.]
#    [  46.   48.   45. ...,   49.   46.   49.]
#    ...,
#    [  42.   38.   42. ...,   48.   46.   40.]
#    [  41.   43.   41. ...,   51.   48.   44.]
#    [  40.   37.   43. ...,   46.   50.   50.]]]
#
#
#  [[[  56.   58.   50. ...,   55.   48.   54.]
#    [  56.   49.   59. ...,   51.   53.   47.]
#    [  52.   55.   57. ...,   54.   47.   55.]
#    ...,
#    [ 126.  136.  140. ...,   73.  139.  200.]
#    [ 128.  134.  112. ...,   86.   86.  202.]
#    [ 155.  122.  110. ...,   63.   75.  189.]]]
#
#
#  ...,
#  [[[ 118.  123.  120. ...,  113.  115.  113.]
#    [ 120.  123.  119. ...,  114.  114.  112.]
#    [ 119.  124.  119. ...,  115.  113.  114.]
#    ...,
#    [  94.   84.   90. ...,   80.   85.   82.]
#    [  91.   88.   85. ...,   81.   81.   82.]
#    [  75.   79.   83. ...,   79.   81.   84.]]]
#
#
#  [[[ 113.  112.  111. ...,  111.  116.  109.]
#    [ 114.  114.  113. ...,  111.  111.  112.]
#    [ 113.  114.  113. ...,  112.  108.  114.]
#    ...,
#    [ 137.  140.  137. ...,   89.   87.   87.]
#    [ 139.  136.  142. ...,   89.   88.   87.]
#    [ 137.  137.  141. ...,   87.   87.   89.]]]
#
#
#  [[[ 110.  113.  108. ...,  105.  100.  105.]
#    [ 108.  113.  107. ...,  105.  102.  106.]
#    [ 109.  111.  112. ...,  103.  102.  104.]
#    ...,
#    [ 202.  201.  204. ...,   65.   65.   67.]
#    [ 204.  202.  203. ...,   66.   61.   66.]
#    [ 204.  203.  204. ...,   63.   63.   61.]]]]
# <NDArray 8x1x112x92 @cpu_shared(0)>

# %%
example_batch[1]
# Out:
# [[[[ 100.   99.  108. ...,  109.  110.  111.]
#    [ 104.  100.  105. ...,  112.  106.  109.]
#    [ 100.  102.  100. ...,  110.  107.  110.]
#    ...,
#    [  78.   84.   80. ...,   42.   47.   47.]
#    [  74.   83.   74. ...,   43.   45.   44.]
#    [  79.   78.   76. ...,   44.   42.   44.]]]
#
#
#  [[[ 116.  116.  117. ...,  115.  110.  114.]
#    [ 116.  114.  116. ...,  113.  110.  112.]
#    [ 116.  112.  117. ...,  114.  111.  110.]
#    ...,
#    [  23.   22.   28. ...,   74.   69.   61.]
#    [  27.   29.   29. ...,   76.   76.   66.]
#    [  28.   27.   38. ...,   83.   76.   77.]]]
#
#
#  [[[  56.   58.   50. ...,   55.   48.   54.]
#    [  56.   49.   59. ...,   51.   53.   47.]
#    [  52.   55.   57. ...,   54.   47.   55.]
#    ...,
#    [ 126.  136.  140. ...,   73.  139.  200.]
#    [ 128.  134.  112. ...,   86.   86.  202.]
#    [ 155.  122.  110. ...,   63.   75.  189.]]]
#
#
#  ...,
#  [[[  54.   55.   60. ...,   57.   50.   56.]
#    [  54.   57.   59. ...,   51.   52.   55.]
#    [  58.   60.   57. ...,   54.   55.   57.]
#    ...,
#    [ 128.  169.  153. ...,  113.   71.   78.]
#    [  99.  223.  209. ...,  143.  154.  124.]
#    [ 106.  227.  217. ...,  156.  181.  217.]]]
#
#
#  [[[ 110.  112.  113. ...,  112.  109.  115.]
#    [ 108.  116.  113. ...,  109.  114.  111.]
#    [ 114.  110.  112. ...,  111.  113.  110.]
#    ...,
#    [ 141.  142.  141. ...,   86.   91.   83.]
#    [ 141.  141.  139. ...,   86.   87.   88.]
#    [ 137.  143.  137. ...,   92.   87.   90.]]]
#
#
#  [[[ 112.  109.  112. ...,  103.  103.  101.]
#    [ 111.  112.  111. ...,  102.  101.  101.]
#    [ 112.  111.  113. ...,  103.  102.  105.]
#    ...,
#    [ 204.  207.  204. ...,   64.   61.   62.]
#    [ 205.  205.  205. ...,   63.   62.   62.]
#    [ 203.  204.  209. ...,   61.   62.   62.]]]]
# <NDArray 8x1x112x92 @cpu_shared(0)>

# %%
plt.imshow(example_batch[0][0][0].asnumpy(), cmap='gray');

# %%
for j in range(8):
    plt.subplot(1,2,1)
    plt.imshow(example_batch[0][j][0].asnumpy(), cmap='gray'); 
    plt.subplot(1,2,2)
    plt.imshow(example_batch[1][j][0].asnumpy(), cmap='gray'); 
    plt.show()

# %%
print(example_batch[2])
# Out:
# [[ 1.]
#  [ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 1.]
#  [ 0.]
#  [ 0.]]
# <NDArray 8x1 @cpu_shared(0)>

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 0 indiciates dissimilar, and 1 indicates similar.

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Block):  
    def __init__(self, verbose=False,**kwargs):
        super(SiameseNetwork, self).__init__(**kwargs)
        self.verbose = verbose
        # add name_scope on the outer most Sequential
        with self.name_scope():
            # block 1
            b1 = nn.Sequential()
            b1.add(
                nn.Conv2D(4, kernel_size=3, padding=1, activation='relu'),
                nn.BatchNorm(),
                nn.Dropout(0.2)
            )
            
            b2 = nn.Sequential()
            b2.add(
                nn.Conv2D(8, kernel_size=3, padding=1, activation='relu'),
                nn.BatchNorm(),
                nn.Dropout(0.2)
            )
        
            b3 = nn.Sequential()
            b3.add(
                nn.Conv2D(8, kernel_size=3, padding=1, activation='relu'),
                nn.BatchNorm(),
                nn.Dropout(0.2)
            )
       
            b4 = nn.Sequential()
            b4.add(
                nn.Flatten(),
                nn.Dense(500, activation="relu"),
                nn.Dense(500, activation="relu"),
                nn.Dense(5)
            )
            self.net = nn.Sequential()
            self.net.add(b1, b2, b3, b4)
        

    def forward(self, input1, input2):
        output1 = self.net(input1)
        output2 = self.net(input2)
        return output1,output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(nn.Block):

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = nd.sqrt(nd.sum(nd.power(nd.subtract(output1, output2),2))) 
        loss_contrastive = nd.mean(nd.add(nd.subtract(1,label) * nd.power(euclidean_distance, 2),(label) * nd.power(nd.subtract(self.margin, euclidean_distance), 2)))
        return loss_contrastive

# %%
criterion = ContrastiveLoss()
output1= nd.array([1,2,3,4,5])
output2= nd.array([1,3,2,5,5])
label =1
loss = criterion(output1,output2,label)
loss
# Out:
# [ 0.07179679]
# <NDArray 1 @cpu(0)>

# %%
label = nd.array([1])
nd.subtract(1, label)
# Out:
# [ 0.]
# <NDArray 1 @cpu(0)>

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset, shuffle=True, num_workers=8,batch_size=Config.train_batch_size)

# %%
from mxnet import init
net = SiameseNetwork()
criterion = ContrastiveLoss()
batch_size=Config.train_batch_size

# %%
ctx = mx.cpu(0)
counter = []
loss_history = [] 
iteration_number= 0

# %%
net.initialize(init.Xavier(magnitude=2), ctx=ctx)
trainer = gluon.Trainer(net.collect_params(),'sgd', {'learning_rate': 0.005, 'wd': 0.001})

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0 = img0.as_in_context(ctx)
        img1 = img1.as_in_context(ctx)
        label= label.as_in_context(ctx)
        with autograd.record():
            output1,output2 = net(img0, img1)
            loss_contrastive = criterion(output1,output2,label)   
        loss_contrastive.backward()        
        trainer.step(batch_size)
        if i %10 == 0:
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.asnumpy()[0]))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.asnumpy()[0])
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 123.87590026855469
#
# Epoch number 1
#  Current loss 45.65705871582031
#
# Epoch number 2
#  Current loss 30.193437576293945
#
# Epoch number 3
#  Current loss 23.271265029907227
#
# Epoch number 4
#  Current loss 14.168405532836914
#
# Epoch number 5
#  Current loss 11.487398147583008
#
# Epoch number 6
#  Current loss 8.365490913391113
#
# Epoch number 7
#  Current loss 10.259773254394531
#
# Epoch number 8
#  Current loss 6.74852180480957
#
# Epoch number 9
#  Current loss 4.8957133293151855
#
# Epoch number 10
#  Current loss 6.472978591918945
#
# Epoch number 11
#  Current loss 4.695911407470703
#
# Epoch number 12
#  Current loss 4.095972061157227
#
# Epoch number 13
#  Current loss 3.547542095184326
#
# Epoch number 14
#  Current loss 3.0811970233917236
#
# Epoch number 15
#  Current loss 3.176435947418213
#
# Epoch number 16
#  Current loss 3.4138615131378174
#
# Epoch number 17
#  Current loss 3.3122613430023193
#
# Epoch number 18
#  Current loss 2.478403329849243
#
# Epoch number 19
#  Current loss 3.497056484222412
#
# Epoch number 20
#  Current loss 2.4680519104003906
#
# Epoch number 21
#  Current loss 2.0926291942596436
#
# Epoch number 22
#  Current loss 2.113736629486084
#
# Epoch number 23
#  Current loss 1.7929422855377197
#
# Epoch number 24
#  Current loss 2.3458311557769775
#
# Epoch number 25
#  Current loss 2.2589263916015625
#
# Epoch number 26
#  Current loss 1.927343726158142
#
# Epoch number 27
#  Current loss 2.861279010772705
#
# Epoch number 28
#  Current loss 1.7358474731445312
#
# Epoch number 29
#  Current loss 2.4591259956359863
#
# Epoch number 30
#  Current loss 1.4422788619995117
#
# Epoch number 31
#  Current loss 1.9192484617233276
#
# Epoch number 32
#  Current loss 1.645134449005127
#
# Epoch number 33
#  Current loss 1.382751703262329
#
# Epoch number 34
#  Current loss 1.1196163892745972
#
# Epoch number 35
#  Current loss 1.3799784183502197
#
# Epoch number 36
#  Current loss 1.7651901245117188
#
# Epoch number 37
#  Current loss 1.4988267421722412
#
# Epoch number 38
#  Current loss 1.2958983182907104
#
# Epoch number 39
#  Current loss 1.6703531742095947
#
# Epoch number 40
#  Current loss 1.2072772979736328
#
# Epoch number 41
#  Current loss 1.5844197273254395
#
# Epoch number 42
#  Current loss 1.3996176719665527
#
# Epoch number 43
#  Current loss 1.267852544784546
#
# Epoch number 44
#  Current loss 1.16242253780365
#
# Epoch number 45
#  Current loss 1.1171107292175293
#
# Epoch number 46
#  Current loss 1.0194838047027588
#
# Epoch number 47
#  Current loss 1.5135409832000732
#
# Epoch number 48
#  Current loss 1.1590262651443481
#
# Epoch number 49
#  Current loss 1.1586796045303345
#
# Epoch number 50
#  Current loss 1.1044611930847168
#
# Epoch number 51
#  Current loss 1.13534677028656
#
# Epoch number 52
#  Current loss 0.9907796382904053
#
# Epoch number 53
#  Current loss 1.1136126518249512
#
# Epoch number 54
#  Current loss 1.1807920932769775
#
# Epoch number 55
#  Current loss 1.0899533033370972
#
# Epoch number 56
#  Current loss 1.162039875984192
#
# Epoch number 57
#  Current loss 1.188111662864685
#
# Epoch number 58
#  Current loss 1.1264222860336304
#
# Epoch number 59
#  Current loss 1.0760549306869507
#
# Epoch number 60
#  Current loss 0.9854382872581482
#
# Epoch number 61
#  Current loss 1.2086399793624878
#
# Epoch number 62
#  Current loss 1.1816662549972534
#
# Epoch number 63
#  Current loss 1.0436804294586182
#
# Epoch number 64
#  Current loss 1.0671508312225342
#
# Epoch number 65
#  Current loss 1.05615234375
#
# Epoch number 66
#  Current loss 1.2234052419662476
#
# Epoch number 67
#  Current loss 1.0461583137512207
#
# Epoch number 68
#  Current loss 1.1087322235107422
#
# Epoch number 69
#  Current loss 1.1721580028533936
#
# Epoch number 70
#  Current loss 1.0947296619415283
#
# Epoch number 71
#  Current loss 1.1028965711593628
#
# Epoch number 72
#  Current loss 1.1314741373062134
#
# Epoch number 73
#  Current loss 1.100121021270752
#
# Epoch number 74
#  Current loss 1.030988097190857
#
# Epoch number 75
#  Current loss 1.2798821926116943
#
# Epoch number 76
#  Current loss 1.0345323085784912
#
# Epoch number 77
#  Current loss 1.0047160387039185
#
# Epoch number 78
#  Current loss 1.1084455251693726
#
# Epoch number 79
#  Current loss 1.024552822113037
#
# Epoch number 80
#  Current loss 1.0053411722183228
#
# Epoch number 81
#  Current loss 1.1497290134429932
#
# Epoch number 82
#  Current loss 1.0233157873153687
#
# Epoch number 83
#  Current loss 1.0396031141281128
#
# Epoch number 84
#  Current loss 1.0208135843276978
#
# Epoch number 85
#  Current loss 1.067487359046936
#
# Epoch number 86
#  Current loss 1.1147871017456055
#
# Epoch number 87
#  Current loss 0.9513999223709106
#
# Epoch number 88
#  Current loss 1.0561076402664185
#
# Epoch number 89
#  Current loss 1.0623226165771484
#
# Epoch number 90
#  Current loss 1.0847898721694946
#
# Epoch number 91
#  Current loss 1.0927826166152954
#
# Epoch number 92
#  Current loss 0.9939519166946411
#
# Epoch number 93
#  Current loss 1.0757505893707275
#
# Epoch number 94
#  Current loss 1.0732020139694214
#
# Epoch number 95
#  Current loss 0.9958382248878479
#
# Epoch number 96
#  Current loss 1.0404635667800903
#
# Epoch number 97
#  Current loss 1.0589022636413574
#
# Epoch number 98
#  Current loss 1.1007201671600342
#
# Epoch number 99
#  Current loss 1.0071284770965576

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = ImageFolderDataset(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=False,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    
    plt.subplot(1,2,1)
    plt.imshow(x0[0][0].asnumpy(), cmap='gray'); 
    plt.subplot(1,2,2)
    plt.imshow(x1[0][0].asnumpy(), cmap='gray'); 
    
    
    
    x0 = x0.as_in_context(ctx)
    x1 = x1.as_in_context(ctx)
    
    output1,output2 = net(x0,x1)
    euclidean_distance = nd.sqrt(nd.sum(nd.power(nd.subtract(output1, output2),2))) 
    print('Dissimilarity: {:.2f}'.format(euclidean_distance.asnumpy()[0]))
    plt.show()
# Out:
# Dissimilarity: 0.06
# Dissimilarity: 0.04
# Dissimilarity: 0.03
# Dissimilarity: 0.02
# Dissimilarity: 0.05
# Dissimilarity: 0.02
# Dissimilarity: 0.04
# Dissimilarity: 0.07
# Dissimilarity: 0.00
# Dissimilarity: 0.00

# %%
training_dir = "/Users/dongshouyang/jupyternotebook/cv/face_recognition/training/"
folder_dataset = ImageFolderDataset(root=Config.training_dir)

# %%
imageFolderDataset=folder_dataset
len(imageFolderDataset)
# Out:
# 360

# %%
img0_tuple = random.choice(imageFolderDataset)
img0 = (img0_tuple[0]).asnumpy()
img0= Image.fromarray(img0)
img0 = img0.convert("L")
img0
# Out:
# <PIL.Image.Image image mode=L size=92x112 at 0x1A1E0DE710>

# %%
img0 = (img0_tuple[0]).asnumpy()
img0= Image.fromarray(img0)
img0
# Out:
# <PIL.Image.Image image mode=RGB size=92x112 at 0x1A1F8528D0>

# %%
img0 = np.asarray(img0)
img0
# Out:
# array([[[110, 110, 110],
#         [111, 111, 111],
#         [110, 110, 110],
#         ...,
#         [103, 103, 103],
#         [102, 102, 102],
#         [100, 100, 100]],
#
#        [[110, 110, 110],
#         [110, 110, 110],
#         [112, 112, 112],
#         ...,
#         [101, 101, 101],
#         [104, 104, 104],
#         [100, 100, 100]],
#
#        [[111, 111, 111],
#         [109, 109, 109],
#         [111, 111, 111],
#         ...,
#         [100, 100, 100],
#         [102, 102, 102],
#         [104, 104, 104]],
#
#        ...,
#        [[198, 198, 198],
#         [201, 201, 201],
#         [203, 203, 203],
#         ...,
#         [ 62,  62,  62],
#         [ 65,  65,  65],
#         [ 62,  62,  62]],
#
#        [[201, 201, 201],
#         [201, 201, 201],
#         [203, 203, 203],
#         ...,
#         [ 64,  64,  64],
#         [ 60,  60,  60],
#         [ 62,  62,  62]],
#
#        [[202, 202, 202],
#         [203, 203, 203],
#         [203, 203, 203],
#         ...,
#         [ 63,  63,  63],
#         [ 59,  59,  59],
#         [ 60,  60,  60]]], dtype=uint8)

# %%
img1_tuple = random.choice(imageFolderDataset)
img1_image = (img1_tuple[0]).asnumpy()
img1_image = Image.fromarray(img1_image)
img1 = np.asarray(img1_image)
img1
# Out:
# array([[[41, 41, 41],
#         [49, 49, 49],
#         [45, 45, 45],
#         ...,
#         [39, 39, 39],
#         [40, 40, 40],
#         [42, 42, 42]],
#
#        [[38, 38, 38],
#         [49, 49, 49],
#         [44, 44, 44],
#         ...,
#         [37, 37, 37],
#         [41, 41, 41],
#         [40, 40, 40]],
#
#        [[48, 48, 48],
#         [45, 45, 45],
#         [48, 48, 48],
#         ...,
#         [42, 42, 42],
#         [37, 37, 37],
#         [40, 40, 40]],
#
#        ...,
#        [[51, 51, 51],
#         [55, 55, 55],
#         [40, 40, 40],
#         ...,
#         [24, 24, 24],
#         [24, 24, 24],
#         [24, 24, 24]],
#
#        [[53, 53, 53],
#         [53, 53, 53],
#         [27, 27, 27],
#         ...,
#         [23, 23, 23],
#         [24, 24, 24],
#         [25, 25, 25]],
#
#        [[52, 52, 52],
#         [56, 56, 56],
#         [11, 11, 11],
#         ...,
#         [18, 18, 18],
#         [28, 28, 28],
#         [21, 21, 21]]], dtype=uint8)

# %%
#img1 = img1.reshape((1, 112, 92))
#img1

# %%
img0_tuple[1]
# Out:
# 28

# %%
img0_tuple = random.choice(imageFolderDataset)
img0_image = (img0_tuple[0]).asnumpy()
img0_image = Image.fromarray(img0_image)
#we need to make sure approx 50% of images are in the same class
should_get_same_class = random.randint(0,1) 
if should_get_same_class:
    while True:
        #keep looping till the same class image is found
        img1_tuple = random.choice(imageFolderDataset)
        img1_image = (img1_tuple[0]).asnumpy()
        img1_image = Image.fromarray(img1_image)
        if img0_tuple[1]==img1_tuple[1]:
             break
else:
    img1_tuple = random.choice(imageFolderDataset)
    img1_image = (img1_tuple[0]).asnumpy()
    img1_image = Image.fromarray(img1_image)

# %%
img0 = (img0_tuple[0]).asnumpy()
img1 = (img1_tuple[0]).asnumpy()
img0=Image.fromarray(img0)
img1=Image.fromarray(img1)
img0 = img0.convert("L")
img1 = img1.convert("L")
img0
# Out:
# <PIL.Image.Image image mode=L size=92x112 at 0x1A20E85898>

# %%
img0 = (img0_tuple[0]).asnumpy()
img0= Image.fromarray(img0)
img0
# Out:
# <PIL.Image.Image image mode=RGB size=92x112 at 0x1A21573978>

# %%
nd.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32)
# Out:
# [ 0.]
# <NDArray 1 @cpu(0)>

# %%
nd.array([ 1.00424588]).asnumpy()[0]
# Out:
# 1.0042459
